# %%
import numpy as np

# Set up matplotlib and use a nicer set of plot parameters
# %config InlineBackend.rc = {}
import matplotlib
# matplotlib.rc_file("../../templates/matplotlibrc")
import matplotlib.pyplot as plt
# %matplotlib inline

# to download example fits from astropy tutorial
from astropy.utils.data import download_file

# %%
from astropy.io import fits
m13_data = fits.getdata('stacked_M13_blue.fits')

# %%
plt.imshow(m13_data)#, cmap='gray')
plt.colorbar()

# %%
dr2_data = fits.getdata('legac_dr2_cat.fits')
plt.imshow(dr2_data)#, cmap='gray')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-597169074a69> in <module>
#       1 dr2_data = fits.getdata('legac_dr2_cat.fits')
# ----> 2 plt.imshow(dr2_data)#, cmap='gray')
#       3 plt.colorbar()
#
# ~/opt/anaconda3/envs/fall2020analysis/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2706         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2707         data=None, **kwargs):
# -> 2708     __ret = gca().imshow(
#    2709         X, cmap=cmap, norm=norm, aspect=aspect,
#    2710         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/opt/anaconda3/envs/fall2020analysis/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
miles_image = fits.getdata('tau_2gyr_MILES_output.fits')
plt.imshow(miles_image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5072d98e17cf> in <module>
#       1 miles_image = fits.getdata('tau_2gyr_MILES_output.fits')
# ----> 2 plt.imshow(miles_image)
#
# ~/opt/anaconda3/envs/fall2020analysis/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2706         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2707         data=None, **kwargs):
# -> 2708     __ret = gca().imshow(
#    2709         X, cmap=cmap, norm=norm, aspect=aspect,
#    2710         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/opt/anaconda3/envs/fall2020analysis/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
hdu_list = fits.open('tau_2gyr_MILES_output.fits')
hdu_list.info()
# Out:
# Filename: tau_2gyr_MILES_output.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      63   (4300,)   float32

# %%
data = hdu_list[0].data

# %%
plt.plot(data)

# %%
data_rect = data.reshape((-1, 100))
plt.imshow(data_rect)

# %%
spectra = fits.open('./spectraDR/legac_M10_186749_v2.0.fits')
spectra.info()
spectra[0].header
# Out:
# Filename: ./spectraDR/legac_M10_186749_v2.0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     131   ()
#   1  PHASE3SPECTRA    1 BinTableHDU     46   1R x 4C   [6166E, 6166E, 6166E, 6166I]
# SIMPLE  =                    T /Written by IDL:  Wed Jun 13 14:44:23 2018
# BITPIX  =                    8 /
# NAXIS   =                    0 /
# EXTEND  =                    T /File contains extensions
# DATE    = '2018-06-13'         /
# ORIGIN  = 'ESO     '           /European Southern Observatory
# TELESCOP= 'ESO-VLT-U3'         /ESO <TEL>
# INSTRUME= 'VIMOS   '           /Instrument used
# DISPELEM= 'HR_red  '           /
# SPECSYS = 'TOPOCENT'           /
# OBJECT  = 'M10_186749'         /
# EXT_OBJ =                    T /
# RA      =           150.373077 /UltraVISTA catalog R.A.
# DEC     =             2.541444 /UltraVISTA catalog Dec.
# EQUINOX =                 2000 /Standard FK5
# RADECSYS= 'FK5     '           /
# ...

# %%
import os

# %%
os.getcwd().split('/')[-1]
path_name = os.getcwd().split('/')[-1] + '_pairwise_plots'
print(path_name)
# Out:
# practice_astropy_pairwise_plots
